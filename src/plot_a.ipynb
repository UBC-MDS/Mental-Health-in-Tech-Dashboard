# %%
import pandas as pd
import altair as alt

# %%
data = pd.read_csv("../data/processed/mental_health_clean.csv")
data.head()
# Out:
#    self_employed num_employees  tech_org mental_health_benefits_healthcare  \
# 0              0        26-100       1.0   Not eligible for coverage / N/A
# 1              0          6-25       1.0                                No
# 2              0          6-25       1.0                                No
# 3              1           NaN       NaN                               NaN
# 4              0          6-25       0.0                               Yes
#
#   mental_health_resources         mental_health_leave mental_disorder_discuss  \
# 0                      No                   Very easy                      No
# 1                     Yes               Somewhat easy                      No
# 2                      No  Neither easy nor difficult                   Maybe
# 3                     NaN                         NaN                     NaN
# 4                      No  Neither easy nor difficult                     Yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 30 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   self_employed                      1433 non-null   int64
#  1   num_employees                      1146 non-null   object
#  2   tech_org                           1146 non-null   float64
#  3   mental_health_benefits_healthcare  1146 non-null   object
#  4   mental_health_resources            1146 non-null   object
#  5   mental_health_leave                1146 non-null   object
#  6   mental_disorder_discuss            1146 non-null   object
#  7   health_disorder_discuss            1146 non-null   object
#  8   discuss_coworker                   1146 non-null   object
#  9   discuss_supervisor                 1146 non-null   object
#  10  online_resources                   287 non-null    object
# ...

# %%
q_selection = "mental_vs_physical"
alt.Chart(data).mark_bar().encode(
    alt.Y(q_selection, title=''),
    alt.X('count()')).properties(
    width=200,
    height=200).facet(column=alt.Column('gender', title=None))
# Out:
# alt.FacetChart(...)

# %%
data['productivity_percent'].unique()
# Out:
# array([nan, '1-25%', '76-100%', '26-50%', '51-75%'], dtype=object)
